# %% [markdown]
# # LDAP with OpenDJ
#
# + github repository: `https://github.com/OpenIdentityPlatform/OpenDJ`
#
# + running as a container as follows:
#
# ```bash
# export IMAGE_NAME=openidentityplatform/opendj
# export CONTAINER_NAME=opendj
# export CONTAINER_HOSTNAME=ldap01.domain.com
# export BASE_DN=dc=inflinx,dc=com
#
# # Pull latest container
# docker pull $IMAGE_NAME
#
# # Start container
# docker run -h $CONTAINER_HOSTNAME -p 1389:1389 -p 1636:1636 -p 4444:4444 \
# -e BASE_DN=$BASE_DN --name $CONTAINER_NAME -t $IMAGE_NAME
#
# # docker run -h ldap-01.domain.com -p 1389:1389 -p 1636:1636 -p 4444:4444 \
# # --name ldap-01 openidentityplatform/opendj
#
# docker logs --follow $CONTAINER_NAME
#
# ```
#
# + use apacheds studio tools located here:
# `https://directory.apache.org/studio/downloads.html`
#
# + importing ldap3:
# `pip3 install ldap3`
#
#  website for python ldap3:
# `https://ldap3.readthedocs.io/en/latest/index.html`
#
# + ldif files extracted from:
# `https://github.com/apress/practical-spring-ldap`
#
# + test ldif files:
# `employees.ldif` and `patrons.ldif`
#
#
# + import ldif files into the ldap server using `import` feature of apacheds studio.
# the second import should be an update since it is uses the same `dc=inflinx,dc=com`
#
# + when use `ldap3` library, make sure not to have spaces between the `dc`s

# %%
from ldap3 import Server, Connection, MODIFY_ADD, MODIFY_REPLACE, ALL_ATTRIBUTES
from ldap3.utils.dn import safe_rdn

# %%
server = Server('localhost:1389')

# %%
conn = Connection(server, 'cn=Directory Manager', 'password', auto_bind=True)

# %%
server.schema
# Out:
# DSA Schema from: cn=schema
#   Attribute types:{'name': Attribute type: 2.5.4.41
#   Short name: name
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.41', 'ATTRIBUTE_TYPE', 'name', 'RFC4519')
# , 'distinguishedName': Attribute type: 2.5.4.49
#   Short name: distinguishedName
#   Single value: False
#   Equality rule: distinguishedNameMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.12 [('1.3.6.1.4.1.1466.115.121.1.12', 'LDAP_SYNTAX', 'DN', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.49', 'ATTRIBUTE_TYPE', 'distinguishedName', 'RFC4519')
# , 'objectClass': Attribute type: 2.5.4.0
#   Short name: objectClass
#   Single value: False
#   Equality rule: objectIdentifierMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.38 [('1.3.6.1.4.1.1466.115.121.1.38', 'LDAP_SYNTAX', 'OID', 'RFC4517')]
#   Mandatory in: top
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.0', 'ATTRIBUTE_TYPE', 'objectClass', 'RFC4512')
# , 'aliasedObjectName': Attribute type: 2.5.4.1
#   Short name: aliasedObjectName
#   Single value: True
#   Equality rule: distinguishedNameMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.12 [('1.3.6.1.4.1.1466.115.121.1.12', 'LDAP_SYNTAX', 'DN', 'RFC4517')]
#   Mandatory in: alias
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.1', 'ATTRIBUTE_TYPE', ['aliasedEntryName', 'aliasedObjectName'], 'X.501-RFC4512')
# , 'knowledgeInformation': Attribute type: 2.5.4.2
#   Short name: knowledgeInformation
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: dSA
#   Extensions:
#     X-ORIGIN: RFC 2256
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.2', 'ATTRIBUTE_TYPE', 'knowledgeInformation', 'RFC2256')
# , 'cn': Attribute type: 2.5.4.3
#   Short name: cn, commonName
#   Single value: False
#   Superior: name
#   Mandatory in: person, organizationalRole, groupOfNames, applicationProcess, applicationEntity, device, groupOfUniqueNames, cRLDistributionPoint, documentSeries, room, subentry, groupOfURLs, groupOfEntries, ds-cfg-access-control-handler, ds-cfg-alert-handler, ds-cfg-branch, ds-cfg-certificate-mapper, ds-cfg-connection-handler, ds-cfg-entry-cache, ds-cfg-extended-operation-handler, ds-cfg-key-manager-provider, ds-cfg-log-publisher, ds-cfg-monitor-provider, ds-cfg-password-storage-scheme, ds-cfg-password-validator, ds-cfg-plugin, ds-cfg-root-config, ds-cfg-root-dse-backend, ds-cfg-sasl-mechanism-handler, ds-cfg-trust-manager-provider, ds-cfg-identity-mapper, ds-cfg-synchronization-provider, ds-cfg-password-generator, ds-cfg-authentication-policy, ds-cfg-work-queue, ds-cfg-account-status-notification-handler, ds-monitor-entry, ds-cfg-group-implementation, ds-cfg-root-dn, ds-cfg-virtual-attribute, ds-cfg-log-retention-policy, ds-cfg-log-rotation-policy, ds-cfg-network-group, ds-cfg-workflow, ds-cfg-workflow-element, ds-cfg-extension, ds-cfg-administration-connector, ds-cfg-qos-policy, ds-mon-branch, ds-cfg-external-changelog-domain, ds-cfg-access-log-filtering-criteria, ds-cfg-schema-provider, ds-cfg-http-authorization-mechanism, container, javaContainer, corbaContainer, posixAccount, ipService, ipProtocol, oncRpc, ipHost, nisNetgroup, nisObject, nisKeyObject, DUAConfigProfile, nisMailAlias, nisNetId, SolarisAuthAttr, SolarisProfAttr, SolarisNamingProfile, nisplusTimeZoneData
#   Optional in: document, rFC822LocalPart, namedObject, untypedObject, ldapSubEntry, ds-cfg-replication-domain, ds-cfg-replication-server, ds-cfg-crypto-manager, ipNetwork, sambaSamAccount, mailGroup
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.3', 'ATTRIBUTE_TYPE', ['cn', 'commonName'], 'RFC4519')
# , 'sn': Attribute type: 2.5.4.4
#   Short name: sn, surname
#   Single value: False
#   Superior: name
#   Mandatory in: person
#   Optional in: rFC822LocalPart
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.4', 'ATTRIBUTE_TYPE', ['sn', 'surname'], 'RFC4519')
# , 'serialNumber': Attribute type: 2.5.4.5
#   Short name: serialNumber
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.44 [('1.3.6.1.4.1.1466.115.121.1.44', 'LDAP_SYNTAX', 'Printable String', 'RFC4517')]
#   Optional in: device
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.5', 'ATTRIBUTE_TYPE', 'serialNumber', 'RFC4519')
# , 'c': Attribute type: 2.5.4.6
#   Short name: c, countryName
#   Single value: True
#   Superior: name
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.11 [('1.3.6.1.4.1.1466.115.121.1.11', 'LDAP_SYNTAX', 'Country String', 'RFC4517')]
#   Mandatory in: country
#   Optional in: untypedObject
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.6', 'ATTRIBUTE_TYPE', ['c', 'countryName'], 'RFC4519')
# , 'l': Attribute type: 2.5.4.7
#   Short name: l, localityName
#   Single value: False
#   Superior: name
#   Mandatory in: residentialPerson
#   Optional in: locality, organization, organizationalUnit, organizationalPerson, organizationalRole, applicationProcess, applicationEntity, device, dmd, account, document, documentSeries, domain, untypedObject, ipHost, ipNetwork
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.7', 'ATTRIBUTE_TYPE', ['L', 'localityName'], 'RFC4519')
# , 'st': Attribute type: 2.5.4.8
#   Short name: st, stateOrProvinceName
#   Single value: False
#   Superior: name
#   Optional in: locality, organization, organizationalUnit, organizationalPerson, organizationalRole, residentialPerson, dmd, domain, untypedObject
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.8', 'ATTRIBUTE_TYPE', ['st', 'stateOrProvinceName'], 'RFC4519-RFC2256')
# , 'street': Attribute type: 2.5.4.9
#   Short name: street, streetAddress
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: locality, organization, organizationalUnit, organizationalPerson, organizationalRole, residentialPerson, dmd, domain, rFC822LocalPart, untypedObject
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.9', 'ATTRIBUTE_TYPE', ['street', 'streetAddress'], 'RFC4519-RFC2256')
# , 'o': Attribute type: 2.5.4.10
#   Short name: o, organizationName
#   Single value: False
#   Superior: name
#   Mandatory in: organization
#   Optional in: groupOfNames, applicationEntity, device, groupOfUniqueNames, account, document, documentSeries, domain, inetOrgPerson, untypedObject, groupOfURLs, groupOfEntries
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.10', 'ATTRIBUTE_TYPE', ['o', 'organizationName'], 'RFC4519')
# , 'ou': Attribute type: 2.5.4.11
#   Short name: ou, organizationalUnitName
#   Single value: False
#   Superior: name
#   Mandatory in: organizationalUnit
#   Optional in: organizationalPerson, organizationalRole, groupOfNames, applicationProcess, applicationEntity, device, groupOfUniqueNames, account, document, documentSeries, untypedObject, groupOfURLs, groupOfEntries
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.11', 'ATTRIBUTE_TYPE', ['ou', 'organizationalUnitName'], 'RFC4519')
# , 'title': Attribute type: 2.5.4.12
#   Short name: title
#   Single value: False
#   Superior: name
#   Optional in: organizationalPerson
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.12', 'ATTRIBUTE_TYPE', 'title', 'RFC4519')
# , 'description': Attribute type: 2.5.4.13
#   Short name: description
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Mandatory in: slpService
#   Optional in: country, locality, organization, organizationalUnit, person, organizationalRole, groupOfNames, applicationProcess, applicationEntity, device, groupOfUniqueNames, dmd, account, document, documentSeries, domain, rFC822LocalPart, room, untypedObject, groupOfURLs, groupOfEntries, javaObject, corbaObject, posixAccount, shadowAccount, posixGroup, ipService, ipProtocol, oncRpc, ipHost, ipNetwork, nisNetgroup, nisMap, nisObject, nisKeyObject, automountMap, automount, sambaSamAccount, sambaGroupMapping, sambaConfig, sambaShare, sambaConfigOption, SolarisProject, nisplusTimeZoneData
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.13', 'ATTRIBUTE_TYPE', 'description', 'RFC4519')
# , 'searchGuide': Attribute type: 2.5.4.14
#   Short name: searchGuide
#   Single value: False
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.25 [('1.3.6.1.4.1.1466.115.121.1.25', 'LDAP_SYNTAX', 'Guide [OBSOLETE]', 'RFC4517')]
#   Optional in: country, locality, organization, organizationalUnit, dmd, domain
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.14', 'ATTRIBUTE_TYPE', 'searchGuide', 'RFC4519')
# , 'businessCategory': Attribute type: 2.5.4.15
#   Short name: businessCategory
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: organization, organizationalUnit, groupOfNames, residentialPerson, groupOfUniqueNames, dmd, domain, inetOrgPerson, groupOfURLs, pilotPerson, groupOfEntries
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.15', 'ATTRIBUTE_TYPE', 'businessCategory', 'RFC4519')
# , 'postalAddress': Attribute type: 2.5.4.16
#   Short name: postalAddress
#   Single value: False
#   Equality rule: caseIgnoreListMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.41 [('1.3.6.1.4.1.1466.115.121.1.41', 'LDAP_SYNTAX', 'Postal Address', 'RFC4517')]
#   Optional in: organization, organizationalUnit, organizationalPerson, organizationalRole, residentialPerson, dmd, domain, rFC822LocalPart
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.16', 'ATTRIBUTE_TYPE', 'postalAddress', 'RFC4519')
# , 'postalCode': Attribute type: 2.5.4.17
#   Short name: postalCode
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: organization, organizationalUnit, organizationalPerson, organizationalRole, residentialPerson, dmd, domain, rFC822LocalPart
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.17', 'ATTRIBUTE_TYPE', 'postalCode', 'RFC4519')
# , 'postOfficeBox': Attribute type: 2.5.4.18
#   Short name: postOfficeBox
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: organization, organizationalUnit, organizationalPerson, organizationalRole, residentialPerson, dmd, domain, rFC822LocalPart
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.18', 'ATTRIBUTE_TYPE', 'postOfficeBox', 'RFC4519')
# , 'physicalDeliveryOfficeName': Attribute type: 2.5.4.19
#   Short name: physicalDeliveryOfficeName
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: organization, organizationalUnit, organizationalPerson, organizationalRole, residentialPerson, dmd, domain, rFC822LocalPart
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.19', 'ATTRIBUTE_TYPE', 'physicalDeliveryOfficeName', 'RFC4519')
# , 'telephoneNumber': Attribute type: 2.5.4.20
#   Short name: telephoneNumber
#   Single value: False
#   Equality rule: telephoneNumberMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.50 [('1.3.6.1.4.1.1466.115.121.1.50', 'LDAP_SYNTAX', 'Telephone Number', 'RFC4517')]
#   Optional in: organization, organizationalUnit, person, organizationalPerson, organizationalRole, residentialPerson, dmd, documentSeries, domain, rFC822LocalPart, room
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.20', 'ATTRIBUTE_TYPE', 'telephoneNumber', 'RFC4519')
# , 'telexNumber': Attribute type: 2.5.4.21
#   Short name: telexNumber
#   Single value: False
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.52 [('1.3.6.1.4.1.1466.115.121.1.52', 'LDAP_SYNTAX', 'Telex Number', 'RFC4517')]
#   Optional in: organization, organizationalUnit, organizationalPerson, organizationalRole, residentialPerson, dmd, domain, rFC822LocalPart
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.21', 'ATTRIBUTE_TYPE', 'telexNumber', 'RFC4519')
# , 'teletexTerminalIdentifier': Attribute type: 2.5.4.22
#   Short name: teletexTerminalIdentifier
#   Single value: False
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.51 [('1.3.6.1.4.1.1466.115.121.1.51', 'LDAP_SYNTAX', 'Teletex Terminal Identifier', 'RFC4517')]
#   Optional in: organization, organizationalUnit, organizationalPerson, organizationalRole, residentialPerson, dmd, domain, rFC822LocalPart
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.22', 'ATTRIBUTE_TYPE', 'teletexTerminalIdentifier', 'RFC4519')
# , 'facsimileTelephoneNumber': Attribute type: 2.5.4.23
#   Short name: facsimileTelephoneNumber
#   Single value: False
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.22 [('1.3.6.1.4.1.1466.115.121.1.22', 'LDAP_SYNTAX', 'Facsimile Telephone Number', 'RFC4517')]
#   Optional in: organization, organizationalUnit, organizationalPerson, organizationalRole, residentialPerson, dmd, domain, rFC822LocalPart
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.23', 'ATTRIBUTE_TYPE', 'facsimileTelephoneNumber', 'RFC4519')
# , 'x121Address': Attribute type: 2.5.4.24
#   Short name: x121Address
#   Single value: False
#   Equality rule: numericStringMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.36 [('1.3.6.1.4.1.1466.115.121.1.36', 'LDAP_SYNTAX', 'Numeric String', 'RFC4517')]
#   Optional in: organization, organizationalUnit, organizationalPerson, organizationalRole, residentialPerson, dmd, domain, rFC822LocalPart
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.24', 'ATTRIBUTE_TYPE', 'x121Address', 'RFC4519')
# , 'internationaliSDNNumber': Attribute type: 2.5.4.25
#   Short name: internationaliSDNNumber
#   Single value: False
#   Equality rule: numericStringMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.36 [('1.3.6.1.4.1.1466.115.121.1.36', 'LDAP_SYNTAX', 'Numeric String', 'RFC4517')]
#   Optional in: organization, organizationalUnit, organizationalPerson, organizationalRole, residentialPerson, dmd, domain, rFC822LocalPart
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.25', 'ATTRIBUTE_TYPE', 'internationaliSDNNumber', 'RFC4519')
# , 'registeredAddress': Attribute type: 2.5.4.26
#   Short name: registeredAddress
#   Single value: False
#   Superior: postalAddress
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.41 [('1.3.6.1.4.1.1466.115.121.1.41', 'LDAP_SYNTAX', 'Postal Address', 'RFC4517')]
#   Optional in: organization, organizationalUnit, organizationalPerson, organizationalRole, residentialPerson, dmd, domain, rFC822LocalPart
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.26', 'ATTRIBUTE_TYPE', 'registeredAddress', 'RFC4519')
# , 'destinationIndicator': Attribute type: 2.5.4.27
#   Short name: destinationIndicator
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.44 [('1.3.6.1.4.1.1466.115.121.1.44', 'LDAP_SYNTAX', 'Printable String', 'RFC4517')]
#   Optional in: organization, organizationalUnit, organizationalPerson, organizationalRole, residentialPerson, dmd, domain, rFC822LocalPart
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.27', 'ATTRIBUTE_TYPE', 'destinationIndicator', 'RFC4519')
# , 'preferredDeliveryMethod': Attribute type: 2.5.4.28
#   Short name: preferredDeliveryMethod
#   Single value: True
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.14 [('1.3.6.1.4.1.1466.115.121.1.14', 'LDAP_SYNTAX', 'Delivery Method', 'RFC4517')]
#   Optional in: organization, organizationalUnit, organizationalPerson, organizationalRole, residentialPerson, dmd, domain, rFC822LocalPart, pilotPerson
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.28', 'ATTRIBUTE_TYPE', 'preferredDeliveryMethod', 'RFC4519')
# , 'presentationAddress': Attribute type: 2.5.4.29
#   Short name: presentationAddress
#   Single value: True
#   Equality rule: presentationAddressMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.43 [('1.3.6.1.4.1.1466.115.121.1.43', 'LDAP_SYNTAX', 'Presentation Address [OBSOLETE]', 'RFC2252')]
#   Mandatory in: applicationEntity
#   Extensions:
#     X-ORIGIN: RFC 2256
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.29', 'ATTRIBUTE_TYPE', 'presentationAddress', 'RFC2256')
# , 'supportedApplicationContext': Attribute type: 2.5.4.30
#   Short name: supportedApplicationContext
#   Single value: False
#   Equality rule: objectIdentifierMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.38 [('1.3.6.1.4.1.1466.115.121.1.38', 'LDAP_SYNTAX', 'OID', 'RFC4517')]
#   Optional in: applicationEntity
#   Extensions:
#     X-ORIGIN: RFC 2256
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.30', 'ATTRIBUTE_TYPE', 'supportedApplicationContext', 'RFC2256')
# , 'member': Attribute type: 2.5.4.31
#   Short name: member
#   Single value: False
#   Superior: distinguishedName
#   Optional in: groupOfNames, groupOfEntries
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.31', 'ATTRIBUTE_TYPE', 'member', 'RFC4519')
# , 'owner': Attribute type: 2.5.4.32
#   Short name: owner
#   Single value: False
#   Superior: distinguishedName
#   Optional in: groupOfNames, device, groupOfUniqueNames, untypedObject, groupOfURLs, groupOfEntries
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.32', 'ATTRIBUTE_TYPE', 'owner', 'RFC4519')
# , 'roleOccupant': Attribute type: 2.5.4.33
#   Short name: roleOccupant
#   Single value: False
#   Superior: distinguishedName
#   Optional in: organizationalRole
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.33', 'ATTRIBUTE_TYPE', 'roleOccupant', 'RFC4519')
# , 'seeAlso': Attribute type: 2.5.4.34
#   Short name: seeAlso
#   Single value: False
#   Superior: distinguishedName
#   Optional in: locality, organization, organizationalUnit, person, organizationalRole, groupOfNames, applicationProcess, applicationEntity, device, groupOfUniqueNames, dmd, account, document, documentSeries, domain, rFC822LocalPart, room, untypedObject, groupOfURLs, groupOfEntries
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.34', 'ATTRIBUTE_TYPE', 'seeAlso', 'RFC4519')
# , 'userPassword': Attribute type: 2.5.4.35
#   Short name: userPassword
#   Single value: False
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.40 [('1.3.6.1.4.1.1466.115.121.1.40', 'LDAP_SYNTAX', 'Octet String', 'RFC4517')]
#   Mandatory in: simpleSecurityObject
#   Optional in: organization, organizationalUnit, person, dmd, domain, posixAccount, shadowAccount, posixGroup, ipHost
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.35', 'ATTRIBUTE_TYPE', 'userPassword', 'RFC4519')
# , 'userCertificate': Attribute type: 2.5.4.36
#   Short name: userCertificate
#   Single value: False
#   Equality rule: certificateExactMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.8 [('1.3.6.1.4.1.1466.115.121.1.8', 'LDAP_SYNTAX', 'Certificate [OBSOLETE]', 'RFC2252')]
#   Mandatory in: strongAuthenticationUser
#   Optional in: pkiUser, inetOrgPerson, ds-certificate-user
#   Extensions:
#     X-ORIGIN: RFC 4523
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.36', 'ATTRIBUTE_TYPE', 'userCertificate', 'RFC4523')
# , 'cACertificate': Attribute type: 2.5.4.37
#   Short name: cACertificate
#   Single value: False
#   Equality rule: certificateExactMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.8 [('1.3.6.1.4.1.1466.115.121.1.8', 'LDAP_SYNTAX', 'Certificate [OBSOLETE]', 'RFC2252')]
#   Mandatory in: certificationAuthority
#   Optional in: pkiCA
#   Extensions:
#     X-ORIGIN: RFC 4523
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.37', 'ATTRIBUTE_TYPE', 'cACertificate', 'RFC4523')
# , 'authorityRevocationList': Attribute type: 2.5.4.38
#   Short name: authorityRevocationList
#   Single value: False
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.9 [('1.3.6.1.4.1.1466.115.121.1.9', 'LDAP_SYNTAX', 'Certificate List [OBSOLETE]', 'RFC2252')]
#   Mandatory in: certificationAuthority
#   Optional in: cRLDistributionPoint, pkiCA
#   Extensions:
#     X-ORIGIN: RFC 4523
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.38', 'ATTRIBUTE_TYPE', 'authorityRevocationList', 'RFC4523')
# , 'certificateRevocationList': Attribute type: 2.5.4.39
#   Short name: certificateRevocationList
#   Single value: False
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.9 [('1.3.6.1.4.1.1466.115.121.1.9', 'LDAP_SYNTAX', 'Certificate List [OBSOLETE]', 'RFC2252')]
#   Mandatory in: certificationAuthority
#   Optional in: cRLDistributionPoint, pkiCA
#   Extensions:
#     X-ORIGIN: RFC 4523
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.39', 'ATTRIBUTE_TYPE', 'certificateRevocationList', 'RFC4523')
# , 'crossCertificatePair': Attribute type: 2.5.4.40
#   Short name: crossCertificatePair
#   Single value: False
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.10 [('1.3.6.1.4.1.1466.115.121.1.10', 'LDAP_SYNTAX', 'Certificate Pair [OBSOLETE]', 'RFC2252')]
#   Optional in: certificationAuthority, pkiCA
#   Extensions:
#     X-ORIGIN: RFC 4523
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.40', 'ATTRIBUTE_TYPE', 'crossCertificatePair', 'RFC4523')
# , 'givenName': Attribute type: 2.5.4.42
#   Short name: givenName
#   Single value: False
#   Superior: name
#   Optional in: inetOrgPerson
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.42', 'ATTRIBUTE_TYPE', 'givenName', 'RFC4519')
# , 'initials': Attribute type: 2.5.4.43
#   Short name: initials
#   Single value: False
#   Superior: name
#   Optional in: inetOrgPerson
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.43', 'ATTRIBUTE_TYPE', 'initials', 'RFC4519')
# , 'generationQualifier': Attribute type: 2.5.4.44
#   Short name: generationQualifier
#   Single value: False
#   Superior: name
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.44', 'ATTRIBUTE_TYPE', 'generationQualifier', 'RFC4519')
# , 'x500UniqueIdentifier': Attribute type: 2.5.4.45
#   Short name: x500UniqueIdentifier
#   Single value: False
#   Equality rule: bitStringMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.6 [('1.3.6.1.4.1.1466.115.121.1.6', 'LDAP_SYNTAX', 'Bit String', 'RFC4517')]
#   Optional in: inetOrgPerson
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.45', 'ATTRIBUTE_TYPE', 'x500UniqueIdentifier', 'RFC4519')
# , 'dnQualifier': Attribute type: 2.5.4.46
#   Short name: dnQualifier
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Ordering rule: caseIgnoreOrderingMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.44 [('1.3.6.1.4.1.1466.115.121.1.44', 'LDAP_SYNTAX', 'Printable String', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.46', 'ATTRIBUTE_TYPE', 'dnQualifier', 'RFC4519')
# , 'enhancedSearchGuide': Attribute type: 2.5.4.47
#   Short name: enhancedSearchGuide
#   Single value: False
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.21 [('1.3.6.1.4.1.1466.115.121.1.21', 'LDAP_SYNTAX', 'Enhanced Guide', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.47', 'ATTRIBUTE_TYPE', 'enhancedSearchGuide', 'RFC4519')
# , 'entryUUID': Attribute type: 1.3.6.1.1.16.4
#   Short name: entryUUID
#   Description: UUID of the entry
#   Single value: True
#   No user modification: True
#   Usage: Directory operation
#   Equality rule: uuidMatch
#   Ordering rule: uuidOrderingMatch
#   Syntax: 1.3.6.1.1.16.1 [('1.3.6.1.1.16.1', 'LDAP_SYNTAX', 'Universally Unique Identifier (UUID)', 'RFC4530')]
#   Extensions:
#     X-ORIGIN: RFC 4530
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('1.3.6.1.1.16.4', 'ATTRIBUTE_TYPE', 'entryUUID', 'RFC4530')
# , 'protocolInformation': Attribute type: 2.5.4.48
#   Short name: protocolInformation
#   Single value: False
#   Equality rule: protocolInformationMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.42 [('1.3.6.1.4.1.1466.115.121.1.42', 'LDAP_SYNTAX', 'Protocol Information [OBSOLETE]', 'RFC2252')]
#   Extensions:
#     X-ORIGIN: RFC 2256
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.48', 'ATTRIBUTE_TYPE', 'protocolInformation', 'RFC2256')
# , 'uniqueMember': Attribute type: 2.5.4.50
#   Short name: uniqueMember
#   Single value: False
#   Equality rule: uniqueMemberMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.34 [('1.3.6.1.4.1.1466.115.121.1.34', 'LDAP_SYNTAX', 'Name And Optional UID', 'RFC4517')]
#   Optional in: groupOfUniqueNames
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.50', 'ATTRIBUTE_TYPE', 'uniqueMember', 'RFC4519')
# , 'lastExternalChangelogCookie': Attribute type: 1.3.6.1.4.1.26027.1.1.585
#   Short name: lastExternalChangelogCookie
#   Single value: True
#   Usage: Directory operation
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: OpenDS Directory Server
#     X-SCHEMA-FILE: 00-core.ldif
# , 'firstChangeNumber': Attribute type: 1.3.6.1.4.1.26027.1.1.593
#   Short name: firstChangeNumber
#   Single value: True
#   Usage: Directory operation
#   Equality rule: integerMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.27 [('1.3.6.1.4.1.1466.115.121.1.27', 'LDAP_SYNTAX', 'Integer', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: OpenDS Directory Server
#     X-SCHEMA-FILE: 00-core.ldif
# , 'lastChangeNumber': Attribute type: 1.3.6.1.4.1.26027.1.1.594
#   Short name: lastChangeNumber
#   Single value: True
#   Usage: Directory operation
#   Equality rule: integerMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.27 [('1.3.6.1.4.1.1466.115.121.1.27', 'LDAP_SYNTAX', 'Integer', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: OpenDS Directory Server
#     X-SCHEMA-FILE: 00-core.ldif
# , 'houseIdentifier': Attribute type: 2.5.4.51
#   Short name: houseIdentifier
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.51', 'ATTRIBUTE_TYPE', 'houseIdentifier', 'RFC4519')
# , 'supportedAlgorithms': Attribute type: 2.5.4.52
#   Short name: supportedAlgorithms
#   Single value: False
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.49 [('1.3.6.1.4.1.1466.115.121.1.49', 'LDAP_SYNTAX', 'Supported Algorithm [OBSOLETE]', 'RFC2252')]
#   Optional in: userSecurityInformation
#   Extensions:
#     X-ORIGIN: RFC 4523
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.52', 'ATTRIBUTE_TYPE', 'supportedAlgorithms', 'RFC4523')
# , 'deltaRevocationList': Attribute type: 2.5.4.53
#   Short name: deltaRevocationList
#   Single value: False
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.9 [('1.3.6.1.4.1.1466.115.121.1.9', 'LDAP_SYNTAX', 'Certificate List [OBSOLETE]', 'RFC2252')]
#   Optional in: certificationAuthority-V2, cRLDistributionPoint, deltaCRL
#   Extensions:
#     X-ORIGIN: RFC 4523
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.53', 'ATTRIBUTE_TYPE', 'deltaRevocationList', 'RFC4523')
# , 'dmdName': Attribute type: 2.5.4.54
#   Short name: dmdName
#   Single value: False
#   Superior: name
#   Mandatory in: dmd
#   Extensions:
#     X-ORIGIN: RFC 2256
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.4.54', 'ATTRIBUTE_TYPE', 'dmdName', 'RFC2256')
# , 'createTimestamp': Attribute type: 2.5.18.1
#   Short name: createTimestamp
#   Single value: True
#   No user modification: True
#   Usage: Directory operation
#   Equality rule: generalizedTimeMatch
#   Ordering rule: generalizedTimeOrderingMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.24 [('1.3.6.1.4.1.1466.115.121.1.24', 'LDAP_SYNTAX', 'Generalized Time', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.18.1', 'ATTRIBUTE_TYPE', 'createTimestamp', 'RFC4512')
# , 'modifyTimestamp': Attribute type: 2.5.18.2
#   Short name: modifyTimestamp
#   Single value: True
#   No user modification: True
#   Usage: Directory operation
#   Equality rule: generalizedTimeMatch
#   Ordering rule: generalizedTimeOrderingMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.24 [('1.3.6.1.4.1.1466.115.121.1.24', 'LDAP_SYNTAX', 'Generalized Time', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.18.2', 'ATTRIBUTE_TYPE', 'modifyTimestamp', 'RFC4512')
# , 'creatorsName': Attribute type: 2.5.18.3
#   Short name: creatorsName
#   Single value: True
#   No user modification: True
#   Usage: Directory operation
#   Equality rule: distinguishedNameMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.12 [('1.3.6.1.4.1.1466.115.121.1.12', 'LDAP_SYNTAX', 'DN', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.18.3', 'ATTRIBUTE_TYPE', 'creatorsName', 'RFC4512')
# , 'modifiersName': Attribute type: 2.5.18.4
#   Short name: modifiersName
#   Single value: True
#   No user modification: True
#   Usage: Directory operation
#   Equality rule: distinguishedNameMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.12 [('1.3.6.1.4.1.1466.115.121.1.12', 'LDAP_SYNTAX', 'DN', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.18.4', 'ATTRIBUTE_TYPE', 'modifiersName', 'RFC4512')
# , 'hasSubordinates': Attribute type: 2.5.18.9
#   Short name: hasSubordinates
#   Single value: True
#   No user modification: True
#   Usage: Directory operation
#   Equality rule: booleanMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.7 [('1.3.6.1.4.1.1466.115.121.1.7', 'LDAP_SYNTAX', 'Boolean', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: X.501
#     X-SCHEMA-FILE: 00-core.ldif
# , 'subschemaSubentry': Attribute type: 2.5.18.10
#   Short name: subschemaSubentry
#   Single value: True
#   No user modification: True
#   Usage: Directory operation
#   Equality rule: distinguishedNameMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.12 [('1.3.6.1.4.1.1466.115.121.1.12', 'LDAP_SYNTAX', 'DN', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.18.10', 'ATTRIBUTE_TYPE', 'subschemaSubentry', 'RFC4512')
# , 'attributeTypes': Attribute type: 2.5.21.5
#   Short name: attributeTypes
#   Single value: False
#   Usage: Directory operation
#   Equality rule: objectIdentifierFirstComponentMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.3 [('1.3.6.1.4.1.1466.115.121.1.3', 'LDAP_SYNTAX', 'Attribute Type Description', 'RFC4517')]
#   Optional in: subschema
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.21.5', 'ATTRIBUTE_TYPE', 'attributeTypes', 'RFC4512')
# , 'objectClasses': Attribute type: 2.5.21.6
#   Short name: objectClasses
#   Single value: False
#   Usage: Directory operation
#   Equality rule: objectIdentifierFirstComponentMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.37 [('1.3.6.1.4.1.1466.115.121.1.37', 'LDAP_SYNTAX', 'Object Class Description', 'RFC4517')]
#   Optional in: subschema
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.21.6', 'ATTRIBUTE_TYPE', 'objectClasses', 'RFC4512')
# , 'matchingRules': Attribute type: 2.5.21.4
#   Short name: matchingRules
#   Single value: False
#   Usage: Directory operation
#   Equality rule: objectIdentifierFirstComponentMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.30 [('1.3.6.1.4.1.1466.115.121.1.30', 'LDAP_SYNTAX', 'Matching Rule Description', 'RFC4517')]
#   Optional in: subschema
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.21.4', 'ATTRIBUTE_TYPE', 'matchingRules', 'RFC4512')
# , 'matchingRuleUse': Attribute type: 2.5.21.8
#   Short name: matchingRuleUse
#   Single value: False
#   Usage: Directory operation
#   Equality rule: objectIdentifierFirstComponentMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.31 [('1.3.6.1.4.1.1466.115.121.1.31', 'LDAP_SYNTAX', 'Matching Rule Use Description', 'RFC4517')]
#   Optional in: subschema
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.21.8', 'ATTRIBUTE_TYPE', 'matchingRuleUse', 'RFC4512')
# , 'structuralObjectClass': Attribute type: 2.5.21.9
#   Short name: structuralObjectClass
#   Single value: True
#   No user modification: True
#   Usage: Directory operation
#   Equality rule: objectIdentifierMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.38 [('1.3.6.1.4.1.1466.115.121.1.38', 'LDAP_SYNTAX', 'OID', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.21.9', 'ATTRIBUTE_TYPE', 'structuralObjectClass', 'RFC4512')
# , 'governingStructureRule': Attribute type: 2.5.21.10
#   Short name: governingStructureRule
#   Single value: True
#   No user modification: True
#   Usage: Directory operation
#   Equality rule: integerMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.27 [('1.3.6.1.4.1.1466.115.121.1.27', 'LDAP_SYNTAX', 'Integer', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.21.10', 'ATTRIBUTE_TYPE', 'governingStructureRule', 'RFC4512')
# , 'namingContexts': Attribute type: 1.3.6.1.4.1.1466.101.120.5
#   Short name: namingContexts
#   Single value: False
#   Usage: DSA operation
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.12 [('1.3.6.1.4.1.1466.115.121.1.12', 'LDAP_SYNTAX', 'DN', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('1.3.6.1.4.1.1466.101.120.5', 'ATTRIBUTE_TYPE', 'namingContexts', 'RFC4512')
# , 'altServer': Attribute type: 1.3.6.1.4.1.1466.101.120.6
#   Short name: altServer
#   Single value: False
#   Usage: DSA operation
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.26 [('1.3.6.1.4.1.1466.115.121.1.26', 'LDAP_SYNTAX', 'IA5 String', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('1.3.6.1.4.1.1466.101.120.6', 'ATTRIBUTE_TYPE', 'altServer', 'RFC4512')
# , 'supportedExtension': Attribute type: 1.3.6.1.4.1.1466.101.120.7
#   Short name: supportedExtension
#   Single value: False
#   Usage: DSA operation
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.38 [('1.3.6.1.4.1.1466.115.121.1.38', 'LDAP_SYNTAX', 'OID', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('1.3.6.1.4.1.1466.101.120.7', 'ATTRIBUTE_TYPE', 'supportedExtension', 'RFC4512')
# , 'supportedControl': Attribute type: 1.3.6.1.4.1.1466.101.120.13
#   Short name: supportedControl
#   Single value: False
#   Usage: DSA operation
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.38 [('1.3.6.1.4.1.1466.115.121.1.38', 'LDAP_SYNTAX', 'OID', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('1.3.6.1.4.1.1466.101.120.13', 'ATTRIBUTE_TYPE', 'supportedControl', 'RFC4512')
# , 'supportedSASLMechanisms': Attribute type: 1.3.6.1.4.1.1466.101.120.14
#   Short name: supportedSASLMechanisms
#   Single value: False
#   Usage: DSA operation
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('1.3.6.1.4.1.1466.101.120.14', 'ATTRIBUTE_TYPE', 'supportedSASLMechanisms', 'RFC4512')
# , 'supportedLDAPVersion': Attribute type: 1.3.6.1.4.1.1466.101.120.15
#   Short name: supportedLDAPVersion
#   Single value: False
#   Usage: DSA operation
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.27 [('1.3.6.1.4.1.1466.115.121.1.27', 'LDAP_SYNTAX', 'Integer', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('1.3.6.1.4.1.1466.101.120.15', 'ATTRIBUTE_TYPE', 'supportedLDAPVersion', 'RFC4512')
# , 'supportedFeatures': Attribute type: 1.3.6.1.4.1.4203.1.3.5
#   Short name: supportedFeatures
#   Single value: False
#   Usage: DSA operation
#   Equality rule: objectIdentifierMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.38 [('1.3.6.1.4.1.1466.115.121.1.38', 'LDAP_SYNTAX', 'OID', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('1.3.6.1.4.1.4203.1.3.5', 'ATTRIBUTE_TYPE', 'supportedFeatures', 'RFC4512')
# , 'ldapSyntaxes': Attribute type: 1.3.6.1.4.1.1466.101.120.16
#   Short name: ldapSyntaxes
#   Single value: False
#   Usage: Directory operation
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.54 [('1.3.6.1.4.1.1466.115.121.1.54', 'LDAP_SYNTAX', 'LDAP Syntax Description', 'RFC4517')]
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('1.3.6.1.4.1.1466.101.120.16', 'ATTRIBUTE_TYPE', 'ldapSyntaxes', 'RFC4512')
# , 'dITStructureRules': Attribute type: 2.5.21.1
#   Short name: dITStructureRules
#   Single value: False
#   Usage: Directory operation
#   Equality rule: IntegerFirstComponentMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.17 [('1.3.6.1.4.1.1466.115.121.1.17', 'LDAP_SYNTAX', 'DIT Structure Rule Description', 'RFC4517')]
#   Optional in: subschema
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.21.1', 'ATTRIBUTE_TYPE', 'dITStructureRules', 'RFC4512')
# , 'nameForms': Attribute type: 2.5.21.7
#   Short name: nameForms
#   Single value: False
#   Usage: Directory operation
#   Equality rule: objectIdentifierFirstComponentMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.35 [('1.3.6.1.4.1.1466.115.121.1.35', 'LDAP_SYNTAX', 'Name Form Description', 'RFC4517')]
#   Optional in: subschema
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.21.7', 'ATTRIBUTE_TYPE', 'nameForms', 'RFC4512')
# , 'dITContentRules': Attribute type: 2.5.21.2
#   Short name: dITContentRules
#   Single value: False
#   Usage: Directory operation
#   Equality rule: objectIdentifierFirstComponentMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.16 [('1.3.6.1.4.1.1466.115.121.1.16', 'LDAP_SYNTAX', 'DIT Content Rule Description', 'RFC4517')]
#   Optional in: subschema
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.21.2', 'ATTRIBUTE_TYPE', 'dITContentRules', 'RFC4512')
# , 'dc': Attribute type: 0.9.2342.19200300.100.1.25
#   Short name: dc, domainComponent
#   Single value: True
#   Equality rule: caseIgnoreIA5Match
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.26 [('1.3.6.1.4.1.1466.115.121.1.26', 'LDAP_SYNTAX', 'IA5 String', 'RFC4517')]
#   Mandatory in: domain, dcObject
#   Optional in: untypedObject
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('0.9.2342.19200300.100.1.25', 'ATTRIBUTE_TYPE', ['DC', 'domainComponent'], 'RFC4519')
# , 'carLicense': Attribute type: 2.16.840.1.113730.3.1.1
#   Short name: carLicense
#   Description: vehicle license or registration plate
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: inetOrgPerson
#   Extensions:
#     X-ORIGIN: RFC 2798
#     X-SCHEMA-FILE: 00-core.ldif
# , 'departmentNumber': Attribute type: 2.16.840.1.113730.3.1.2
#   Short name: departmentNumber
#   Description: identifies a department within an organization
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: inetOrgPerson
#   Extensions:
#     X-ORIGIN: RFC 2798
#     X-SCHEMA-FILE: 00-core.ldif
# , 'displayName': Attribute type: 2.16.840.1.113730.3.1.241
#   Short name: displayName
#   Description: preferred name of a person to be used when displaying entries
#   Single value: True
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: inetOrgPerson, sambaSamAccount, sambaGroupMapping
#   Extensions:
#     X-ORIGIN: RFC 2798
#     X-SCHEMA-FILE: 00-core.ldif
# , 'employeeNumber': Attribute type: 2.16.840.1.113730.3.1.3
#   Short name: employeeNumber
#   Description: numerically identifies an employee within an organization
#   Single value: True
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: inetOrgPerson
#   Extensions:
#     X-ORIGIN: RFC 2798
#     X-SCHEMA-FILE: 00-core.ldif
# , 'employeeType': Attribute type: 2.16.840.1.113730.3.1.4
#   Short name: employeeType
#   Description: type of employment for a person
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: inetOrgPerson
#   Extensions:
#     X-ORIGIN: RFC 2798
#     X-SCHEMA-FILE: 00-core.ldif
# , 'jpegPhoto': Attribute type: 0.9.2342.19200300.100.1.60
#   Short name: jpegPhoto
#   Description: a JPEG image
#   Single value: False
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.28 [('1.3.6.1.4.1.1466.115.121.1.28', 'LDAP_SYNTAX', 'JPEG', 'RFC4517')]
#   Optional in: inetOrgPerson, pilotObject
#   Extensions:
#     X-ORIGIN: RFC 2798
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('0.9.2342.19200300.100.1.60', 'ATTRIBUTE_TYPE', 'jpegPhoto', 'RFC2798')
# , 'preferredLanguage': Attribute type: 2.16.840.1.113730.3.1.39
#   Short name: preferredLanguage
#   Description: preferred written or spoken language for a person
#   Single value: True
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: inetOrgPerson
#   Extensions:
#     X-ORIGIN: RFC 2798
#     X-SCHEMA-FILE: 00-core.ldif
# , 'userSMIMECertificate': Attribute type: 2.16.840.1.113730.3.1.40
#   Short name: userSMIMECertificate
#   Description: PKCS#7 SignedData used to support S/MIME
#   Single value: False
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.5 [('1.3.6.1.4.1.1466.115.121.1.5', 'LDAP_SYNTAX', 'Binary [OBSOLETE]', 'RFC2252')]
#   Optional in: inetOrgPerson
#   Extensions:
#     X-ORIGIN: RFC 2798
#     X-SCHEMA-FILE: 00-core.ldif
# , 'userPKCS12': Attribute type: 2.16.840.1.113730.3.1.216
#   Short name: userPKCS12
#   Description: PKCS #12 PFX PDU for exchange of personal identity information
#   Single value: False
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.5 [('1.3.6.1.4.1.1466.115.121.1.5', 'LDAP_SYNTAX', 'Binary [OBSOLETE]', 'RFC2252')]
#   Optional in: inetOrgPerson
#   Extensions:
#     X-ORIGIN: RFC 2798
#     X-SCHEMA-FILE: 00-core.ldif
# , 'associatedDomain': Attribute type: 0.9.2342.19200300.100.1.37
#   Short name: associatedDomain
#   Single value: False
#   Equality rule: caseIgnoreIA5Match
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.26 [('1.3.6.1.4.1.1466.115.121.1.26', 'LDAP_SYNTAX', 'IA5 String', 'RFC4517')]
#   Mandatory in: domainRelatedObject
#   Extensions:
#     X-ORIGIN: RFC 4524
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('0.9.2342.19200300.100.1.37', 'ATTRIBUTE_TYPE', 'associatedDomain', 'RFC4524')
# , 'associatedName': Attribute type: 0.9.2342.19200300.100.1.38
#   Short name: associatedName
#   Single value: False
#   Equality rule: distinguishedNameMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.12 [('1.3.6.1.4.1.1466.115.121.1.12', 'LDAP_SYNTAX', 'DN', 'RFC4517')]
#   Optional in: domain
#   Extensions:
#     X-ORIGIN: RFC 4524
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('0.9.2342.19200300.100.1.38', 'ATTRIBUTE_TYPE', 'associatedName', 'RFC4524')
# , 'buildingName': Attribute type: 0.9.2342.19200300.100.1.48
#   Short name: buildingName
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: pilotOrganization
#   Extensions:
#     X-ORIGIN: RFC 4524
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('0.9.2342.19200300.100.1.48', 'ATTRIBUTE_TYPE', 'buildingName', 'RFC4524')
# , 'co': Attribute type: 0.9.2342.19200300.100.1.43
#   Short name: co, friendlyCountryName
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Mandatory in: friendlyCountry
#   Extensions:
#     X-ORIGIN: RFC 4524
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('0.9.2342.19200300.100.1.43', 'ATTRIBUTE_TYPE', ['co', 'friendlyCountryName'], 'RFC4524')
# , 'documentAuthor': Attribute type: 0.9.2342.19200300.100.1.14
#   Short name: documentAuthor
#   Single value: False
#   Equality rule: distinguishedNameMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.12 [('1.3.6.1.4.1.1466.115.121.1.12', 'LDAP_SYNTAX', 'DN', 'RFC4517')]
#   Optional in: document
#   Extensions:
#     X-ORIGIN: RFC 4524
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('0.9.2342.19200300.100.1.14', 'ATTRIBUTE_TYPE', 'documentAuthor', 'RFC4524')
# , 'documentIdentifier': Attribute type: 0.9.2342.19200300.100.1.11
#   Short name: documentIdentifier
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Mandatory in: document
#   Extensions:
#     X-ORIGIN: RFC 4524
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('0.9.2342.19200300.100.1.11', 'ATTRIBUTE_TYPE', 'documentIdentifier', 'RFC4524')
# , 'documentLocation': Attribute type: 0.9.2342.19200300.100.1.15
#   Short name: documentLocation
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: document
#   Extensions:
#     X-ORIGIN: RFC 4524
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('0.9.2342.19200300.100.1.15', 'ATTRIBUTE_TYPE', 'documentLocation', 'RFC4524')
# , 'documentPublisher': Attribute type: 0.9.2342.19200300.100.1.56
#   Short name: documentPublisher
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: document
#   Extensions:
#     X-ORIGIN: RFC 4524
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('0.9.2342.19200300.100.1.56', 'ATTRIBUTE_TYPE', 'documentPublisher', 'RFC4524')
# , 'documentTitle': Attribute type: 0.9.2342.19200300.100.1.12
#   Short name: documentTitle
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: document
#   Extensions:
#     X-ORIGIN: RFC 4524
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('0.9.2342.19200300.100.1.12', 'ATTRIBUTE_TYPE', 'documentTitle', 'RFC4524')
# , 'documentVersion': Attribute type: 0.9.2342.19200300.100.1.13
#   Short name: documentVersion
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: document
#   Extensions:
#     X-ORIGIN: RFC 4524
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('0.9.2342.19200300.100.1.13', 'ATTRIBUTE_TYPE', 'documentVersion', 'RFC4524')
# , 'drink': Attribute type: 0.9.2342.19200300.100.1.5
#   Short name: drink, favouriteDrink
#   Single value: False
#   Equality rule: caseIgnoreMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.15 [('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')]
#   Optional in: pilotPerson
#   Extensions:
#     X-ORIGIN: RFC 4524
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('0.9.2342.19200300.100.1.5', 'ATTRIBUTE_TYPE', ['drink', 'favouriteDrink'], 'RFC4524')
# , 'homePhone': Attribute type: 0.9.2342.19200300.100.1.20
#   Short name: homePhone, homeTelephoneNumber
#   Single value: False
#   Equality rule: telephoneNumberMatch
#   Syntax: 1.3.6.1.4.1.1466.115.121.1.50 [('1.3.6.1.4.1.1466.115.121.1.50', 'LDAP_SYNTAX', 'Telephone Number', 'RFC4517')]
# ...
#   Short name: uddiTModelInstanceInfoStructureRule
#   Superior rules: 5
#   Name form: uddiTModelInstanceInfoNameForm
#   Extensions:
#     X-ORIGIN: RFC 4403
#     X-SCHEMA-FILE: 03-uddiv3.ldif
# , 'uddiTModelStructureRule': DIT content rule: 7
#   Short name: uddiTModelStructureRule
#   Name form: uddiTModelNameForm
#   Extensions:
#     X-ORIGIN: RFC 4403
#     X-SCHEMA-FILE: 03-uddiv3.ldif
# , 'uddiPublisherAssertionStructureRule': DIT content rule: 8
#   Short name: uddiPublisherAssertionStructureRule
#   Name form: uddiPublisherAssertionNameForm
#   Extensions:
#     X-ORIGIN: RFC 4403
#     X-SCHEMA-FILE: 03-uddiv3.ldif
# , 'uddiv3SubscriptionStructureRule': DIT content rule: 9
#   Short name: uddiv3SubscriptionStructureRule
#   Name form: uddiv3SubscriptionNameForm
#   Extensions:
#     X-ORIGIN: RFC 4403
#     X-SCHEMA-FILE: 03-uddiv3.ldif
# , 'uddiv3EntityObituaryStructureRule': DIT content rule: 10
#   Short name: uddiv3EntityObituaryStructureRule
#   Name form: uddiv3EntityObituaryNameForm
#   Extensions:
#     X-ORIGIN: RFC 4403
#     X-SCHEMA-FILE: 03-uddiv3.ldif
# }
#   Name forms:{'uddiBusinessEntityNameForm': DIT content rule: 1.3.6.1.1.10.15.1
#   Short name: uddiBusinessEntityNameForm
#   Object class: uddiBusinessEntity
#   Must contain: uddiBusinessKey
#   Extensions:
#     X-ORIGIN: RFC 4403
#     X-SCHEMA-FILE: 03-uddiv3.ldif
#   OidInfo: ('1.3.6.1.1.10.15.1', 'NAME_FORM', 'uddiBusinessEntityNameForm', 'RFC4403')
# , 'uddiContactNameForm': DIT content rule: 1.3.6.1.1.10.15.2
#   Short name: uddiContactNameForm
#   Object class: uddiContact
#   Must contain: uddiUUID
#   Extensions:
#     X-ORIGIN: RFC 4403
#     X-SCHEMA-FILE: 03-uddiv3.ldif
#   OidInfo: ('1.3.6.1.1.10.15.2', 'NAME_FORM', 'uddiContactNameForm', 'RFC4403')
# , 'uddiAddressNameForm': DIT content rule: 1.3.6.1.1.10.15.3
#   Short name: uddiAddressNameForm
#   Object class: uddiAddress
#   Must contain: uddiUUID
#   Extensions:
#     X-ORIGIN: RFC 4403
#     X-SCHEMA-FILE: 03-uddiv3.ldif
#   OidInfo: ('1.3.6.1.1.10.15.3', 'NAME_FORM', 'uddiAddressNameForm', 'RFC4403')
# , 'uddiBusinessServiceNameForm': DIT content rule: 1.3.6.1.1.10.15.4
#   Short name: uddiBusinessServiceNameForm
#   Object class: uddiBusinessService
#   Must contain: uddiServiceKey
#   Extensions:
#     X-ORIGIN: RFC 4403
#     X-SCHEMA-FILE: 03-uddiv3.ldif
#   OidInfo: ('1.3.6.1.1.10.15.4', 'NAME_FORM', 'uddiBusinessServiceNameForm', 'RFC4403')
# , 'uddiBindingTemplateNameForm': DIT content rule: 1.3.6.1.1.10.15.5
#   Short name: uddiBindingTemplateNameForm
#   Object class: uddiBindingTemplate
#   Must contain: uddiBindingKey
#   Extensions:
#     X-ORIGIN: RFC 4403
#     X-SCHEMA-FILE: 03-uddiv3.ldif
#   OidInfo: ('1.3.6.1.1.10.15.5', 'NAME_FORM', 'uddiBindingTemplateNameForm', 'RFC4403')
# , 'uddiTModelInstanceInfoNameForm': DIT content rule: 1.3.6.1.1.10.15.6
#   Short name: uddiTModelInstanceInfoNameForm
#   Object class: uddiTModelInstanceInfo
#   Must contain: uddiTModelKey
#   Extensions:
#     X-ORIGIN: RFC 4403
#     X-SCHEMA-FILE: 03-uddiv3.ldif
#   OidInfo: ('1.3.6.1.1.10.15.6', 'NAME_FORM', 'uddiTModelInstanceInfoNameForm', 'RFC4403')
# , 'uddiTModelNameForm': DIT content rule: 1.3.6.1.1.10.15.7
#   Short name: uddiTModelNameForm
#   Object class: uddiTModel
#   Must contain: uddiTModelKey
#   Extensions:
#     X-ORIGIN: RFC 4403
#     X-SCHEMA-FILE: 03-uddiv3.ldif
#   OidInfo: ('1.3.6.1.1.10.15.7', 'NAME_FORM', 'uddiTModelNameForm', 'RFC4403')
# , 'uddiPublisherAssertionNameForm': DIT content rule: 1.3.6.1.1.10.15.8
#   Short name: uddiPublisherAssertionNameForm
#   Object class: uddiPublisherAssertion
#   Must contain: uddiUUID
#   Extensions:
#     X-ORIGIN: RFC 4403
#     X-SCHEMA-FILE: 03-uddiv3.ldif
#   OidInfo: ('1.3.6.1.1.10.15.8', 'NAME_FORM', 'uddiPublisherAssertionNameForm', 'RFC4403')
# , 'uddiv3SubscriptionNameForm': DIT content rule: 1.3.6.1.1.10.15.9
#   Short name: uddiv3SubscriptionNameForm
#   Object class: uddiv3Subscription
#   Must contain: uddiUUID
#   Extensions:
#     X-ORIGIN: RFC 4403
#     X-SCHEMA-FILE: 03-uddiv3.ldif
#   OidInfo: ('1.3.6.1.1.10.15.9', 'NAME_FORM', 'uddiv3SubscriptionNameForm', 'RFC4403')
# , 'uddiv3EntityObituaryNameForm': DIT content rule: 1.3.6.1.1.10.15.10
#   Short name: uddiv3EntityObituaryNameForm
#   Object class: uddiv3EntityObituary
#   Must contain: uddiUUID
#   Extensions:
#     X-ORIGIN: RFC 4403
#     X-SCHEMA-FILE: 03-uddiv3.ldif
#   OidInfo: ('1.3.6.1.1.10.15.10', 'NAME_FORM', 'uddiv3EntityObituaryNameForm', 'RFC4403')
# }
#   LDAP syntaxes:{'1.3.6.1.4.1.1466.115.121.1.3': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.3
#   Description: Attribute Type Description
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.3', 'LDAP_SYNTAX', 'Attribute Type Description', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.5': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.5
#   Description: Binary
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.5', 'LDAP_SYNTAX', 'Binary [OBSOLETE]', 'RFC2252')
# , '1.3.6.1.4.1.1466.115.121.1.6': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.6
#   Description: Bit String
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.6', 'LDAP_SYNTAX', 'Bit String', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.7': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.7
#   Description: Boolean
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.7', 'LDAP_SYNTAX', 'Boolean', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.11': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.11
#   Description: Country String
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.11', 'LDAP_SYNTAX', 'Country String', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.14': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.14
#   Description: Delivery Method
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.14', 'LDAP_SYNTAX', 'Delivery Method', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.15': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.15
#   Description: Directory String
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.15', 'LDAP_SYNTAX', 'Directory String', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.16': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.16
#   Description: DIT Content Rule Description
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.16', 'LDAP_SYNTAX', 'DIT Content Rule Description', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.17': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.17
#   Description: DIT Structure Rule Description
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.17', 'LDAP_SYNTAX', 'DIT Structure Rule Description', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.12': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.12
#   Description: DN
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.12', 'LDAP_SYNTAX', 'DN', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.21': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.21
#   Description: Enhanced Guide
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.21', 'LDAP_SYNTAX', 'Enhanced Guide', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.22': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.22
#   Description: Facsimile Telephone Number
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.22', 'LDAP_SYNTAX', 'Facsimile Telephone Number', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.23': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.23
#   Description: Fax
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.23', 'LDAP_SYNTAX', 'Fax', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.24': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.24
#   Description: Generalized Time
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.24', 'LDAP_SYNTAX', 'Generalized Time', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.25': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.25
#   Description: Guide
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.25', 'LDAP_SYNTAX', 'Guide [OBSOLETE]', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.26': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.26
#   Description: IA5 String
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.26', 'LDAP_SYNTAX', 'IA5 String', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.27': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.27
#   Description: Integer
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.27', 'LDAP_SYNTAX', 'Integer', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.28': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.28
#   Description: JPEG
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.28', 'LDAP_SYNTAX', 'JPEG', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.30': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.30
#   Description: Matching Rule Description
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.30', 'LDAP_SYNTAX', 'Matching Rule Description', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.31': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.31
#   Description: Matching Rule Use Description
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.31', 'LDAP_SYNTAX', 'Matching Rule Use Description', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.54': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.54
#   Description: LDAP Syntax Description
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.54', 'LDAP_SYNTAX', 'LDAP Syntax Description', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.34': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.34
#   Description: Name and Optional UID
#   Extensions:
#     X-ORIGIN: RFC 4517
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.34', 'LDAP_SYNTAX', 'Name And Optional UID', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.35': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.35
#   Description: Name Form Description
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.35', 'LDAP_SYNTAX', 'Name Form Description', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.36': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.36
#   Description: Numeric String
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.36', 'LDAP_SYNTAX', 'Numeric String', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.37': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.37
#   Description: Object Class Description
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.37', 'LDAP_SYNTAX', 'Object Class Description', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.40': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.40
#   Description: Octet String
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.40', 'LDAP_SYNTAX', 'Octet String', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.38': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.38
#   Description: OID
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.38', 'LDAP_SYNTAX', 'OID', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.39': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.39
#   Description: Other Mailbox
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.39', 'LDAP_SYNTAX', 'Other Mailbox', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.41': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.41
#   Description: Postal Address
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.41', 'LDAP_SYNTAX', 'Postal Address', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.43': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.43
#   Description: Presentation Address
#   Extensions:
#     X-ORIGIN: RFC 2252
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.43', 'LDAP_SYNTAX', 'Presentation Address [OBSOLETE]', 'RFC2252')
# , '1.3.6.1.4.1.1466.115.121.1.44': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.44
#   Description: Printable String
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.44', 'LDAP_SYNTAX', 'Printable String', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.42': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.42
#   Description: Protocol Information
#   Extensions:
#     X-ORIGIN: RFC 2252
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.42', 'LDAP_SYNTAX', 'Protocol Information [OBSOLETE]', 'RFC2252')
# , '1.3.6.1.4.1.1466.115.121.1.58': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.58
#   Description: Substring Assertion
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.58', 'LDAP_SYNTAX', 'Substring Assertion', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.50': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.50
#   Description: Telephone Number
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.50', 'LDAP_SYNTAX', 'Telephone Number', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.51': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.51
#   Description: Teletex Terminal Identifier
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.51', 'LDAP_SYNTAX', 'Teletex Terminal Identifier', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.52': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.52
#   Description: Telex Number
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.52', 'LDAP_SYNTAX', 'Telex Number', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.53': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.53
#   Description: UTC Time
#   Extensions:
#     X-ORIGIN: RFC 4512
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.53', 'LDAP_SYNTAX', 'UTC Time [DEPRECATED]', 'RFC4517')
# , '1.3.6.1.4.1.1466.115.121.1.9': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.9
#   Description: Certificate List
#   Extensions:
#     X-ORIGIN: RFC 4523
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.9', 'LDAP_SYNTAX', 'Certificate List [OBSOLETE]', 'RFC2252')
# , '1.3.6.1.4.1.1466.115.121.1.10': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.10
#   Description: Certificate Pair
#   Extensions:
#     X-ORIGIN: RFC 4523
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.10', 'LDAP_SYNTAX', 'Certificate Pair [OBSOLETE]', 'RFC2252')
# , '1.3.6.1.4.1.1466.115.121.1.8': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.8
#   Description: Certificate
#   Extensions:
#     X-ORIGIN: RFC 4523
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.8', 'LDAP_SYNTAX', 'Certificate [OBSOLETE]', 'RFC2252')
# , '1.3.6.1.1.15.1': LDAP syntax: 1.3.6.1.1.15.1
#   Description: X.509 Certificate Exact Assertion
#   Extensions:
#     X-ORIGIN: RFC 4523
# , '1.3.6.1.4.1.1466.115.121.1.49': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.49
#   Description: Supported Algorithm
#   Extensions:
#     X-ORIGIN: RFC 4523
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.49', 'LDAP_SYNTAX', 'Supported Algorithm [OBSOLETE]', 'RFC2252')
# , '1.3.6.1.1.16.1': LDAP syntax: 1.3.6.1.1.16.1
#   Description: UUID
#   Extensions:
#     X-ORIGIN: RFC 4530
#   OidInfo: ('1.3.6.1.1.16.1', 'LDAP_SYNTAX', 'Universally Unique Identifier (UUID)', 'RFC4530')
# , '1.3.6.1.4.1.4203.1.1.2': LDAP syntax: 1.3.6.1.4.1.4203.1.1.2
#   Description: Authentication Password Syntax
#   Extensions:
#     X-ORIGIN: RFC 3112
# , '1.3.6.1.4.1.26027.1.3.1': LDAP syntax: 1.3.6.1.4.1.26027.1.3.1
#   Description: User Password
#   Extensions:
#     X-ORIGIN: OpenDS Directory Server
# , '1.3.6.1.4.1.26027.1.3.4': LDAP syntax: 1.3.6.1.4.1.26027.1.3.4
#   Description: Sun-defined Access Control Information
# , '1.3.6.1.4.1.1466.115.121.1.45': LDAP syntax: 1.3.6.1.4.1.1466.115.121.1.45
#   Description: Subtree Specification
#   OidInfo: ('1.3.6.1.4.1.1466.115.121.1.45', 'LDAP_SYNTAX', 'Subtree specification [OBSOLETE]', 'RFC2252')
# , '1.3.6.1.4.1.36733.2.1.3.1': LDAP syntax: 1.3.6.1.4.1.36733.2.1.3.1
#   Description: Json
#   Extensions:
#     X-ORIGIN: OpenDJ Directory Server
# , '1.3.6.1.4.1.36733.2.1.3.2': LDAP syntax: 1.3.6.1.4.1.36733.2.1.3.2
#   Description: Json Query
#   Extensions:
#     X-ORIGIN: OpenDJ Directory Server
# , '1.3.6.1.4.1.26027.1.3.6': LDAP syntax: 1.3.6.1.4.1.26027.1.3.6
#   Description: Collective Conflict Behavior
#   Extensions:
#     X-ENUM: real-overrides-virtual, virtual-overrides-real, merge-real-and-virtual
#     X-SCHEMA-FILE: 00-core.ldif
# }
# Other:
#   objectClass:
#     top
#     ldapSubentry
#     subschema
#   cn:
#     schema
#   creatorsName:
# cn=schema
#   modifiersName:
# cn=schema
#   subschemaSubentry:
# cn=schema
#   hasSubordinates:
# False
#   entryUUID:
# 224309e4-3ca9-37ac-8102-2acac3bd3b89
#   numSubordinates:
# 0
#   etag:
# 00000000a29265d3
#   structuralObjectClass:
# ldapSubEntry
#   entryDN:
# cn=schema

# %%
print(server.info)
# Out:
# None

# %%
dir(conn)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bind_controls',
#  '_context_state',
#  '_deferred_bind',
#  '_deferred_open',
#  '_deferred_start_tls',
#  '_do_auto_bind',
#  '_entries',
#  '_executing_deferred',
#  '_fire_deferred',
#  '_get_entries',
#  '_prepare_return_value',
#  '_usage',
#  'abandon',
#  'add',
#  'authentication',
#  'auto_bind',
#  'auto_encode',
#  'auto_escape',
#  'auto_range',
#  'auto_referrals',
#  'bind',
#  'bound',
#  'check_names',
#  'closed',
#  'compare',
#  'connection_lock',
#  'cred_store',
#  'delete',
#  'do_ntlm_bind',
#  'do_sasl_bind',
#  'empty_attributes',
#  'entries',
#  'extend',
#  'extended',
#  'fast_decoder',
#  'get_response',
#  'last_error',
#  'lazy',
#  'listening',
#  'modify',
#  'modify_dn',
#  'open',
#  'password',
#  'pool_keepalive',
#  'pool_lifetime',
#  'pool_name',
#  'pool_size',
#  'post_send_search',
#  'post_send_single_response',
#  'raise_exceptions',
#  'read_only',
#  'rebind',
#  'receive_timeout',
#  'refresh_server_info',
#  'repr_with_sensitive_data_stripped',
#  'request',
#  'response',
#  'response_to_file',
#  'response_to_json',
#  'response_to_ldif',
#  'result',
#  'sasl_credentials',
#  'sasl_in_progress',
#  'sasl_mechanism',
#  'search',
#  'send',
#  'server',
#  'server_pool',
#  'socket',
#  'source_address',
#  'source_port_list',
#  'start_tls',
#  'starting_tls',
#  'strategy',
#  'strategy_type',
#  'stream',
#  'tls_started',
#  'unbind',
#  'usage',
#  'use_referral_cache',
#  'user',
#  'version']

# %%
conn.version
# Out:
# 3

# %%
print(server.schema.object_classes['inetorgperson'])
# Out:
# Object class: 2.16.840.1.113730.3.2.2
#   Short name: inetOrgPerson
#   Type: Structural
#   Superior: organizationalPerson
#   May contain attributes: audio, businessCategory, carLicense, departmentNumber, displayName, employeeNumber, employeeType, givenName, homePhone, homePostalAddress, initials, jpegPhoto, labeledURI, mail, manager, mobile, o, pager, photo, roomNumber, secretary, uid, userCertificate, x500UniqueIdentifier, preferredLanguage, userSMIMECertificate, userPKCS12
#   Extensions:
#     X-ORIGIN: RFC 2798
#     X-SCHEMA-FILE: 00-core.ldif

# %%
print(server.schema.object_classes['organizationalperson'])
# Out:
# Object class: 2.5.6.7
#   Short name: organizationalPerson
#   Type: Structural
#   Superior: person
#   May contain attributes: title, x121Address, registeredAddress, destinationIndicator, preferredDeliveryMethod, telexNumber, teletexTerminalIdentifier, telephoneNumber, internationaliSDNNumber, facsimileTelephoneNumber, street, postOfficeBox, postalCode, postalAddress, physicalDeliveryOfficeName, ou, st, l
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.6.7', 'OBJECT_CLASS', 'organizationalPerson', 'RFC4519')

# %%
print(server.schema.object_classes['person'])
# Out:
# Object class: 2.5.6.6
#   Short name: person
#   Type: Structural
#   Superior: top
#   Must contain attributes: sn, cn
#   May contain attributes: userPassword, telephoneNumber, seeAlso, description
#   Extensions:
#     X-ORIGIN: RFC 4519
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.6.6', 'OBJECT_CLASS', 'person', 'RFC4519')

# %%
print(server.schema.object_classes['top'])
# Out:
# Object class: 2.5.6.0
#   Short name: top
#   Type: Abstract
#   Must contain attributes: objectClass
#   Extensions:
#     X-ORIGIN: RFC 4512
#     X-SCHEMA-FILE: 00-core.ldif
#   OidInfo: ('2.5.6.0', 'OBJECT_CLASS', 'top', 'RFC4512')

# %%
# Search entries with email ends with @inflinx.com
print(conn.search('ou=employees,dc=inflinx,dc=com', '(&(mail=*@inflinx.com))'))
# Out:
# False

# %%
# Search entries with email ends with @inflinx.com
print(conn.search('ou=patrons,dc=inflinx,dc=com', '(&(mail=*@inflinx.com))'))
# Out:
# False

# %%
# Display the first element of the search results
print(conn.entries[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-c6015f3d0947> in <module>
#       1 # Display the first element of the search results
# ----> 2 print(conn.entries[0])
#
# IndexError: list index out of range

# %%
len(conn.entries)
# Out:
# 101
